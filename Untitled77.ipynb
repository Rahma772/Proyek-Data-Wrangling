# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahma772/Proyek-Data-Wrangling/blob/main/Untitled77.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/US_Top_50_Universities_2026.csv")
df
# Out:
#                                    University_Name  National_Rank  \
# 0      Massachusetts Institute of Technology (MIT)              1
# 1                              Columbia University              2
# 2                             Princeton University              3
# 3                              Stanford University              4
# 4               University of California, Berkeley              5
# 5                               Harvard University              6
# 6                                 Williams College              7
# 7                         Johns Hopkins University              8
# 8                                  Yale University              9
# 9                       University of Pennsylvania             10
# 10                           Vanderbilt University             11
# 11                                 Rice University             12
# 12                           University of Chicago             13
# ...

# %% [markdown]
# Perintah head() digunakan untuk menampilkan 5 baris pertama dari dataset secara default. Tujuannya adalah untuk melihat gambaran awal data, seperti nama kolom, isi data, serta format penulisan data pada setiap variabel.

# %%
df.head()
# Out:
#                                University_Name  National_Rank  Founded_Year  \
# 0  Massachusetts Institute of Technology (MIT)              1          1861
# 1                          Columbia University              2          1754
# 2                         Princeton University              3          1746
# 3                          Stanford University              4          1891
# 4           University of California, Berkeley              5          1868
#
#   Institution_Type State  Research_Impact_Score  Intl_Student_Ratio  \
# 0          Private    MA                  100.0                91.6
# 1          Private    NY                   95.9                83.7
# 2          Private    NJ                   99.0                70.0
# 3          Private    CA                   99.5                73.5
# 4           Public    CA                   98.9                70.6
#
#    Employment_Rate
# 0             96.2
# 1             92.1
# 2             94.5
# ...

# %% [markdown]
# Perintah info() digunakan untuk menampilkan informasi lengkap mengenai struktur dataset.
#
# 1. Informasi yang ditampilkan meliputi:
#
# 2. Jumlah baris data
#
# 3. Jumlah kolom
#
# 4. Nama setiap kolom
#
# 5. Jumlah data yang tidak kosong (non-null)
#
# 6. Tipe data setiap kolom
#
# 7. Penggunaan memori
#
#
# Adapun tipe data pada dataset dibawah yaitu:
# 1. Tipe Data Numerik terdiri dari int64 (2 kolom) yaitu National_Rank dan, Founded_Year, kemudian float64 (3 kolom) yaitu Research_Impact_Score dan Intl_Student_Ratio dan Employment_Rate. Total kolom numerik: 5 kolom
# 2. Tipe Data Kategorikal terdiri dari University_Name, Institution_Type dan State. Total kolom kategorikal yaitu 3 kolom.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   University_Name        50 non-null     object
#  1   National_Rank          50 non-null     int64
#  2   Founded_Year           50 non-null     int64
#  3   Institution_Type       50 non-null     object
#  4   State                  50 non-null     object
#  5   Research_Impact_Score  50 non-null     float64
#  6   Intl_Student_Ratio     50 non-null     float64
#  7   Employment_Rate        50 non-null     float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 3.3+ KB

# %% [markdown]
# Perintah shape digunakan untuk mengetahui jumlah baris dan kolom pada dataset.
# Hasil output dibawah menampilkan jumlah baris sebanyak 50 menunjukkan bahwa dataset berisi 50 entitas atau objek, yaitu 50 universitas yang masuk dalam daftar peringkat nasional. Setiap baris merepresentasikan satu universitas. Adapun jumlah kolom sebanyak 8 menunjukkan bahwa setiap universitas memiliki 8 atribut atau variabel penjelas, yaitu:
# 1. University_Name
# 2. National_Rank
# 3. Founded_Year
# 4. Institution_Type
# 5. State
# 6. Research_Impact_Score
# 7. Intl_Student_Ratio
# 8. Employment_Rate

# %%
df.shape
# Out:
# (50, 8)

# %% [markdown]
# Membuat struktur dataset secara manual dengan menggunakan format JSON

# %%
import json
df = [
    {
        "Transaction_ID": "TRX001",
        "Customer_Name": "Andi Saputra",
        "Product_Category": "Electronics",
        "Quantity": 2,
        "Price": 3500000,
        "Total_Amount": 7000000,
        "Transaction_Date": "2025-01-10",
        "Payment_Method": "Credit Card"
    },
    {
        "Transaction_ID": "TRX002",
        "Customer_Name": "Siti Rahma",
        "Product_Category": "Fashion",
        "Quantity": 3,
        "Price": 250000,
        "Total_Amount": 750000,
        "Transaction_Date": "2025-01-12",
        "Payment_Method": "E-Wallet"
    },
    {
        "Transaction_ID": "TRX003",
        "Customer_Name": "Budi Santoso",
        "Product_Category": "Home & Living",
        "Quantity": 1,
        "Price": 1200000,
        "Total_Amount": 1200000,
        "Transaction_Date": "2025-01-15",
        "Payment_Method": "Bank Transfer"
    }
]
with open("ecommerce_manual.json", "w") as file:
    json.dump(df, file, indent=4)

df
# Out:
# [{'Transaction_ID': 'TRX001',
#   'Customer_Name': 'Andi Saputra',
#   'Product_Category': 'Electronics',
#   'Quantity': 2,
#   'Price': 3500000,
#   'Total_Amount': 7000000,
#   'Transaction_Date': '2025-01-10',
#   'Payment_Method': 'Credit Card'},
#  {'Transaction_ID': 'TRX002',
#   'Customer_Name': 'Siti Rahma',
#   'Product_Category': 'Fashion',
#   'Quantity': 3,
#   'Price': 250000,
#   'Total_Amount': 750000,
#   'Transaction_Date': '2025-01-12',
#   'Payment_Method': 'E-Wallet'},
#  {'Transaction_ID': 'TRX003',
#   'Customer_Name': 'Budi Santoso',
#   'Product_Category': 'Home & Living',
#   'Quantity': 1,
#   'Price': 1200000,
#   'Total_Amount': 1200000,
#   'Transaction_Date': '2025-01-15',
#   'Payment_Method': 'Bank Transfer'}]

# %%
import pandas as pd
df = pd.read_json("ecommerce_manual.json")
df.head()
# Out:
#   Transaction_ID Customer_Name Product_Category  Quantity    Price  \
# 0         TRX001  Andi Saputra      Electronics         2  3500000
# 1         TRX002    Siti Rahma          Fashion         3   250000
# 2         TRX003  Budi Santoso    Home & Living         1  1200000
#
#    Total_Amount Transaction_Date Payment_Method
# 0       7000000       2025-01-10    Credit Card
# 1        750000       2025-01-12       E-Wallet
# 2       1200000       2025-01-15  Bank Transfer

# %% [markdown]
# Kode di bawah ini digunakan untuk mengonversi JSON ke CSV

# %%
df.to_csv("ecommerce_manual.csv", index=False)
df
# Out:
#   Transaction_ID Customer_Name Product_Category  Quantity    Price  \
# 0         TRX001  Andi Saputra      Electronics         2  3500000
# 1         TRX002    Siti Rahma          Fashion         3   250000
# 2         TRX003  Budi Santoso    Home & Living         1  1200000
#
#    Total_Amount Transaction_Date Payment_Method
# 0       7000000       2025-01-10    Credit Card
# 1        750000       2025-01-12       E-Wallet
# 2       1200000       2025-01-15  Bank Transfer
